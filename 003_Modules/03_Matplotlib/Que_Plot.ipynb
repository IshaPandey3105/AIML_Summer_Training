# %% [markdown]
# # Questions

# %% [markdown]
# ### line Plot

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[10,20,30,40]
plt.plot(x, y, color="red",linestyle="--",marker="*",markersize=20,markerfacecolor="yellow",markeredgecolor="purple",markeredgewidth=5,alpha=0.5,linewidth=2,label='2x')                 # Plot line chart
plt.title("Line Graph") 
plt.xlabel("X Axis")             # for linestyle we can use "--", "-.", ":","-"
plt.ylabel("Y Axis")          
plt.grid(True)                 
plt.show()

# %%
import matplotlib.pyplot as plt
x=["c","c++","java","python"]
y=[10,20,30,40]
plt.plot(x, y, color="red",linestyle="--",marker="o",markersize=20,markerfacecolor="yellow",markeredgecolor="red",markeredgewidth=5,alpha=0.5,linewidth=2,label='2x')                 # Plot line chart
plt.title("Line Graph") 
plt.xlabel("X Axis")           
plt.ylabel("Y Axis")          
plt.grid(True)                 
plt.show()

# %%
import matplotlib.pyplot as plt
x=[16,200,345,489]
y1=[100,200,300,400]
y2=[150,250,340,450]
y3=[100,233,355,456]
y4=[130,244,355,478]
plt.plot(x,y1,color="red")
plt.plot(x,y2,color="yellow")
plt.plot(x,y3,color="purple")
plt.plot(x,y4,color="blue")
plt.title("Multi Line Graph") 
plt.xlabel("X Axis")           
plt.ylabel("Y Axis")          
plt.grid(True)                 
plt.show()

# %%
import matplotlib.pyplot as plt
x=[16,200,345,489]
y1=[100,200,300,400]
y2=[150,250,340,450]
plt.subplot(1,2,1)
plt.plot(x,y1,color="red",linestyle="--",marker="o",markersize=8,markerfacecolor="red",markeredgecolor="black")
plt.subplot(1,2,2)
plt.plot(x,y2,color="purple",linestyle="-.",marker="s",markersize=8,markerfacecolor="purple",markeredgecolor="black")
plt.title("Multi Line Graph") 
plt.xlabel("X Axis")           
plt.ylabel("Y Axis")          
plt.grid(True)                 
plt.show()

# %% [markdown]
# # BAR PLOT

# %%
import matplotlib.pyplot as plt
x=["c","java","c++","python"]
y=[10,50,40,80]
plt.bar(x, y, color="skyblue",edgecolor="brown",width=0.5)               
# plt.barh(x, y,height=0.5, color="skyblue")               
# plt.barh(x,y)  # show horizontally
plt.title("Line Graph") 
plt.xlabel("X Axis")           
plt.ylabel("Y Axis")          
plt.grid(True)                 
plt.show()

# %%
import matplotlib.pyplot as plt
x=["c","java","c++","python"]
y=[10,50,40,80]
x1=["c","java","c++","python"]
y1=[20,30,50,90]
plt.subplot(1,2,1)
plt.bar(x, y, color="skyblue",edgecolor="brown",width=0.5)  
plt.grid(True)   
plt.subplot(1,2,2)            
plt.bar(x1, y1, color="pink",edgecolor="black",width=0.5)                      
plt.grid(True)                                
plt.show()

# %%
import matplotlib.pyplot as plt
x=["c","java","c++","python"]
y=[100,50,40,80]
x1=["c","java","c++","python"]
y1=[20,40,20,30]

plt.bar(x, y, color="skyblue",edgecolor="brown",width=0.5)  
         
plt.bar(x1, y1, color="pink",edgecolor="black",width=0.5)                      
                              
plt.show()

# %%
import matplotlib.pyplot as plt
x=["c","java","c++","python"]
y=[100,50,40,80]
x1=["c","java","c++","python"]
y1=[20,40,20,30]

plt.barh(x, y, color="skyblue",edgecolor="brown",height=0.5)  
         
plt.barh(x1, y1, color="pink",edgecolor="black",height=0.5)                      
                              
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = ["c", "java", "c++", "python"]
y = [10, 50, 40, 80]
y1 = [20, 30, 50, 90]

x_indexes = np.arange(len(x))  # [0, 1, 2, 3]
width = 0.4  # width of each bar

# First bar set (shift left)
plt.bar(x_indexes - width/2, y, width=width)

# Second bar set (shift right)
plt.bar(x_indexes + width/2, y1, width=width)

# Setting x-axis labels
plt.xticks(x_indexes, x)        # Replace 0,1,2,3 with language names
plt.xlabel("Languages")
plt.ylabel("Scores")
plt.title("Comparison of Two Bar Sets")                 
plt.grid(True, axis='y')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x = ["c", "java", "c++", "python"]
y = [10, 50, 40, 80]
y1 = [20, 30, 50, 90]

x_indexes = np.arange(len(x))  # numeric positions for categories
width = 0.4  # bar width

# Plot both bars side by side
plt.bar(x_indexes - width/2, y, width=width, color="skyblue", edgecolor="brown", label='Set 1')
plt.bar(x_indexes + width/2, y1, width=width, color="pink", edgecolor="black", label='Set 2')

# Customizations
plt.xticks(x_indexes, x)  # Set x-axis labels to languages
# plt.xlabel("Languages")
plt.ylabel("Scores")
plt.title("Side-by-Side Bar Chart")
plt.grid(True, axis='y')
plt.legend()            #Shows which color represents "Set 1" and which is "Set 2".

plt.xlabel("______________This is a very long X-axis label that........................ might be cut off      ")

plt.tight_layout()          #Adjusts spacing to prevent label/title overlap or cutoff
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = ["c", "java", "c++", "python"]
y = [10, 50, 40, 80]
z = [20, 30, 50, 90]

width = 0.4  # width of each bar

p = np.arange(len(x))  # [0, 1, 2, 3]
p1=[ i+width for i in p ] # [0.4, 1.4, 2.4, 3.4]  
c=['y','b','y','b']
c1=['r','m','r','m']

plt.bar(p,y,width,color=c,edgecolor="r",label="PL1",align="center",alpha=0.7,hatch='*')  # alpha = transparency
plt.bar(p1,z,width,color=c1,edgecolor="b",label="PL2",align="center",alpha=0.7,hatch='/')

# Setting x-axis labels
plt.xticks(p+width/2, x,rotation=20)        # Replace 0,1,2,3 with language names and little rotation
plt.xlabel("Languages",fontsize="10")
plt.ylabel("Scores",fontsize="10")
plt.title("Comparison of Two Bar Sets",fontsize="10")                 
plt.grid(True, axis='y')
plt.legend()
plt.show()

# %% [markdown]
# # Scater Plot

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 15, 12, 18]

plt.scatter(x, y, color='red', s=250, marker='D',linewidth=5) # we can't give edge colour here
plt.title("Scatter Plot with Single Color",fontsize=30)
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.grid(False)

plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 15, 12, 18]
colors = ['r', 'g', 'b', 'purple']  # red, green, blue, purple

plt.scatter(x, y, c=colors, s=300, marker='p', edgecolor='black', linewidth=2, alpha=0.8)
# plt.title("Scatter Plot with Different Colors")
# plt.xlabel("X Axis")
# plt.ylabel("Y Axis")
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt

y = [100, 50, 40, 80]
y1 = [30, 40, 20, 50]
colors = [65, 50, 80, 36]                       # colormap[cmap]-->(BrBG,viridis, plasma, coolwarm ,inferno,cividis,hot,cool,jet etc.)
size = [200, 160, 430, 300]

scatter = plt.scatter(y, y1, c=colors, s=size, marker='*', linewidth=1, cmap='rainbow')  
plt.colorbar(scatter, label="ColorBar")  # Colorbar needs a mappable object like scatter
# plt.colorbar(scatter)	---> Shows the gradient scale on the side
plt.show()

# %%
import matplotlib.pyplot as plt
y=[100,50,40,80]
y1=[20,40,20,30]
y2=[200,430,220,300]
colors=[10,50,40,36]
size=[100,120,130,100]
scatter1=plt.scatter(y, y1,c=colors,s=size, marker='*',linewidth=1,cmap="BrBG")                                                     
scatter2=plt.scatter(y, y2,c=colors,s=size, marker='o',linewidth=1,cmap="viridis")    
t=plt.colorbar(scatter1,label="ColorBar_1")
t=plt.colorbar(scatter2, label="ColorBar_2")
# t.set_label("ColorBar")                                                 
plt.show()

# %% [markdown]
# # Histogram

# %%
import matplotlib.pyplot as plt                                                                              
# Sample data (like student marks or ages)                                          # histtype -->	'bar', 'step', 'stepfilled'
data = [12, 15, 17, 18, 21, 22, 22, 25, 27, 29, 30, 30, 32, 35, 35, 37, 40]         # by default orientation is vertical
plt.hist(data, bins=5, color='skyblue', edgecolor='brown',cumulative=0,bottom=20,	histtype="bar"	,alpha=0.9,	rwidth=0.98,label="Marks",	orientation="vertical")#,log=True)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data: Marks of students
marks = [45, 50, 52, 58, 60, 60, 61, 65, 70, 72, 75, 78, 80, 85, 90]

# Custom bins → You decide the ranges
bins = [40, 50, 60, 70, 80, 90, 100]

plt.hist(marks, bins=bins, color='m', edgecolor='black', rwidth=0.9)

plt.title('Marks Distribution Histogram')
plt.xlabel('Marks Range')
plt.ylabel('Number of Students')
plt.grid(axis='y')

plt.show()

# %%
import matplotlib.pyplot as plt
# Sample Data: Marks of two different classes
class_A = [45, 50, 52, 58, 60, 60, 61, 65, 70, 72, 75, 78, 80, 85, 90]
class_B = [40, 48, 55, 57, 59, 62, 67, 68, 74, 76, 79, 81, 84, 88, 92]

# Same bins for both
l = [40, 50, 60, 70, 80, 90, 100]

plt.hist(class_A, bins=l, color='skyblue', edgecolor='black', rwidth=0.9, label='Class A', alpha=0.7)
plt.hist(class_B, bins=l, color='orange', edgecolor='black', rwidth=0.9, label='Class B', alpha=0.5)

plt.title('Marks Distribution: Class A vs Class B')
plt.xlabel('Marks Range')
plt.ylabel('Number of Students')
plt.legend(loc='upper left')
plt.grid(axis='y')

plt.show()

# %% [markdown]
# ###  📊 Beautiful Side-by-Side Histogram

# %%
import matplotlib.pyplot as plt
import numpy as np

# 🎨 Sample Data (Marks)
class_A = [45, 50, 52, 58, 60, 60, 61, 65, 70, 72, 75, 78, 80, 85, 90]
class_B = [40, 48, 55, 57, 59, 62, 67, 68, 74, 76, 79, 81, 84, 88, 92]

# 🎨 Bins (Marks Ranges)
bins = [40, 50, 60, 70, 80, 90, 100]

# 🎨 Frequency Counts
counts_A, _ = np.histogram(class_A, bins)
counts_B, _ = np.histogram(class_B, bins)

# 🎨 Bar Positions
x = np.array(bins[:-1])  # Left edges of the bars
bar_width = 2

# 🎨 Plot with Beautiful Colors
plt.figure(figsize=(10, 6))  # Bigger size

plt.bar(x - bar_width/2, counts_A, width=bar_width, color='#7FB3D5', edgecolor='#154360', label='Class A')  # Soft blue
plt.bar(x + bar_width/2, counts_B, width=bar_width, color='#F5B7B1', edgecolor='#641E16', label='Class B')  # Soft pink

# 🎨 Title & Labels (Pretty Fonts)
plt.title('Marks Distribution: Class A vs Class B', fontsize=16, fontweight='bold', color="#08C024")
plt.xlabel('Marks Range', fontsize=12, color="#13EFB5")
plt.ylabel('Number of Students', fontsize=12, color="#09D2D2")

# 🎨 Legend with nicer font
plt.legend(title='Classes', fontsize=10, title_fontsize=12)

# 🎨 Soft Grid
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Pie Plot

# %%
import matplotlib.pyplot as plt
y = ["Python", "Java", "C++","c"]
x = [60, 15, 15,10]
ex=[0.0,0.0,0.0,0.2]                       # for clockwise startangle must be in minus 
c=['r','b','g','y']
plt.pie(x,labels=y,explode=ex,colors=c,autopct="%0.1f%%",shadow=True,radius=1,labeldistance=0.99,startangle=-90,textprops={"fontsize":10}
        ,counterclock=True,rotatelabels=True,wedgeprops={"linewidth":3,"edgecolor":'b'})#center=(2,2))
plt.title("Programming Language Usage",fontsize=12)
plt.show()

# %% [markdown]
# ## Donut Pie Chart

# %%
import matplotlib.pyplot as plt
y = ["Python", "Java", "C++","c"]
x = [60, 25, 15,10]
plt.pie(x,labels=y,radius=1.5)
plt.pie([6],colors='w')
plt.show()

# %%
import matplotlib.pyplot as plt
y = ["Python", "Java", "C++","c"]
x = [40, 25, 35,10]
x1 = [20, 25, 45,10]
c=['r','b','g','y']
plt.pie(x,labels=y,radius=1.5)
plt.pie(x1,radius=0.5,colors=c)
plt.show()

# %% [markdown]
# ### Srem Plot

# %%
# import matplotlib.pyplot as plt
x = [10,40, 25, 35,10]
x1 = [10,20, 25, 45,10]
plt.stem(x,x1,linefmt="-.",markerfmt='r',bottom=20,basefmt="g",label="Stem",orientation="vertical")
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### Step Plot

# %%
import matplotlib.pyplot as plt
x = [10,40, 25, 35,10]
y = [10,20, 25, 45,10]
x1 = [20,40, 35, 35,10]
y1 = [50,60, 45, 75,10]
plt.step(x,y,color="g")
plt.step(x1,y1,color="r")

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load Titanic dataset
titanic = sns.load_dataset('titanic')

# Check data
# print(titanic.head())
# print(titanic.info())
# print(titanic['survived'].value_counts())

# Handling missing values (Age column has NaNs)
titanic['age'].fillna(titanic['age'].mean(), inplace=True)

# Visualization: Survival by Gender
sns.countplot(x='survived', hue='sex', data=titanic)
plt.show()

# Survival by Class
sns.countplot(x='survived', hue='pclass', data=titanic)
plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_1452\546964917.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic['age'].fillna(titanic['age'].mean(), inplace=True)

# %% [markdown]
# ## QUESTIONS

# %%
#1 line Chart
import matplotlib.pyplot as plt
x=[2015,2016,2017,2018,2019,2020]
y=[10,80,30,40,56,93]
plt.plot(x, y,marker="o" )
plt.title("Line Graph") 
plt.xlabel("X Axis")            
plt.ylabel("Y Axis")          
plt.grid(True)                 
plt.show()

# %%
#2
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[10,20,50,40,20]
# to show value on bars -   
plt.bar(x, y, color="pink")
plt.xlabel("X Axis")             
plt.ylabel("Y Axis")                         
plt.show()

# %%
#3
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[10,20,30,40]
y1=[40,50,10,30]
plt.plot(x, y, color="red",linestyle="--",marker="*",markersize=10,label="first")
plt.plot(x, y1, color="blue",linestyle="--",marker="o",label="second")
plt.title("Multi Line Graph") 
plt.xlabel("X Axis")             
plt.ylabel("Y Axis")  
plt.legend()        
plt.grid(True)                 
plt.show()

# %%
#4
import matplotlib.pyplot as plt
x=["Walking","Study","Sleep","Eating"]
y=[10,50,20,90]
ex=[0.0,0.0,0.5,0.0]
plt.pie(y,labels=x,explode=ex,autopct="%0.1f%%")         
plt.grid(True)                 
plt.show()

# %%
#5 
import matplotlib.pyplot as plt
marks = [45, 50, 52, 58, 60, 60, 61, 65, 70, 72, 75, 78, 80, 85, 90]
bins = [40, 50, 60, 70, 80, 90, 100]
plt.hist(marks, bins=bins, color='pink', edgecolor='red', rwidth=0.9)
plt.title('Marks Distribution Histogram')
plt.xlabel('Marks Range')
plt.ylabel('Number of Students')
# plt.grid(axis='y')

plt.show()

# %% [markdown]
# # END
