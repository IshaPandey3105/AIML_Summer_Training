# %% [markdown]
# # 📌 What is Matplotlib?
# #### Matplotlib is a Python library used to create data visualizations such as:
# Line plots 📈
# Bar charts 📊
# Pie charts 🥧
# Scatter plots 🔘
# Histograms 🔢
#
# #### ✅ Why We Use a Particular Module:
# ##### We use 'pyplot' from the matplotlib library(big library) for simple and quick plotting.
# ##### It provides functions similar to MATLAB for creating plots.

# %% [markdown]
# ## 📌 Common Plot Types with Matplotlib
# # Plot Type	        Function
# # Line Plot	        plt.plot()
# # Bar Chart	        plt.bar()
# # Histogram	        plt.hist()
# # Scatter Plot	    plt.scatter()
# # Pie Chart	        plt.pie()

# %%
# 🔹Line Plot
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[10,20,30,40]
plt.plot(x, y)                 # Plot line chart
plt.title("Simple Line Graph") # Add a title
plt.xlabel("X Axis")           # Label X
plt.ylabel("Y Axis")           # Label Y
plt.grid(True)                 # Show grid
plt.show()                     # Display the plot

# %%
# 🔹Bar Chart
import matplotlib.pyplot as plt
x = ["AI", "ML", "DL"]
y = [90, 85, 80]

plt.bar(x, y, color='purple',edgecolor='yellow')
plt.title("Subject Scores")
plt.show()

# %%
# 🔹Scatter Plot
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]
y = [10, 15, 13, 20, 25]

plt.scatter(x, y, color='green')
plt.title("Scatter Example")
plt.show()

# %%
# 🔹Pie Chart
import matplotlib.pyplot as plt
_label = ["Python", "Java", "C++"]
sizes = [60, 25, 15]
plt.pie(sizes, labels=_label, autopct="%.0f%%")
plt.title("Programming Language Usage")
plt.show()

# %%
# 🔹Histogram
import matplotlib.pyplot as plt

# Sample data (like student marks or ages)
data = [12, 15, 17, 18, 21, 22, 22, 25, 27, 29, 30, 30, 32, 35, 35, 37, 40]

# Create histogram
plt.hist(data, bins=5, color='skyblue', edgecolor='brown')

# Add labels and title
plt.title("Histogram Example")
plt.xlabel("Value")
plt.ylabel("Frequency")

# Show the plot
plt.show()

# %%
# # line graph by taking 5 values from users and given x=0,1,2,3,4.
# import matplotlib.pyplot as plt
# x=[0,1,2,3,4]             // taking lots of time
# y=[] 
# for i in range(5):
#     n=int(input("Enter NO.: "))
#     y.append(n)
# plt.plot(x,y)
# plt.show

# %%
import matplotlib.pyplot as plt

x = [0, 1, 2, 3, 4]
y = [5, 10, 7, 12, 8]  # Directly giving 5 values here

plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line Graph of Sample Values')
plt.grid(True)
plt.show()
