# %% [markdown]
# # 🔰 Deep Learning Roadmap (Complete – Topics )
#
# ## 1. Introduction to Deep Learning
# - What is Deep Learning?
# - Difference Between Machine Learning and Deep Learning
# - Applications of Deep Learning
#
# ## 2. Neural Network Basics
# - Biological Neuron vs Artificial Neuron
# - Structure of a Neural Network:
#   - Input Layer, Hidden Layers, Output Layer
# - Neuron Function (Z = w·x + b)
# - Forward Propagation
# - Role of Weights and Biases
#
# ## 3. Activation Functions
# - Need for Activation Functions
# - Types of Activation Functions:
#   - Sigmoid
#   - Tanh
#   - ReLU
#   - Leaky ReLU
#   - Softmax
#
# ## 4. Training a Neural Network
# - Loss Functions:
#   - Mean Squared Error (MSE)
#   - Binary Cross Entropy
#   - Categorical Cross Entropy
# - Optimization:
#   - Gradient Descent (Batch, Stochastic, Mini-Batch)
#   - Learning Rate
# - Epochs, Batches
# - Backpropagation Algorithm
#   - Derivatives and Chain Rule
#   - Update Rule
#
# ## 5. Regularization Techniques
# - Overfitting vs Underfitting
# - Techniques to Reduce Overfitting:
#   - L1 and L2 Regularization
#   - Dropout
#   - Early Stopping
#   - Data Augmentation (brief overview)
#
# ## 6. Evaluation Metrics for Deep Learning
# - Accuracy, Precision, Recall, F1-Score
# - Confusion Matrix
# - ROC Curve and AUC
#
# ## 7. Deep Learning Frameworks (Intro only)
# - TensorFlow
# - Keras
# - PyTorch
#
# ## 8. Convolutional Neural Networks (CNN)
# - Introduction to Image Data
# - Convolution Operation
# - Filters/Kernels
# - Padding, Stride
# - Max Pooling
# - CNN Architecture (Conv + Pool + FC Layers)
# - Applications of CNN (Image Classification, Face Detection)
#
# ## 9. Recurrent Neural Networks (RNN)
# - Introduction to Sequential Data
# - Working of RNN
# - Vanishing Gradient Problem
# - LSTM (Long Short-Term Memory)
# - GRU (Gated Recurrent Unit)
# - Applications: Text, Speech, Time Series
#
# ## 10. Transfer Learning
# - What is Transfer Learning?
# - Pretrained Models (e.g., VGG16, ResNet)
# - Fine-Tuning vs Feature Extraction
#
# ## 11. Basics of Natural Language Processing (NLP)
# - Tokenization, Stemming, Lemmatization
# - Bag of Words, TF-IDF
# - Word Embeddings (Word2Vec, GloVe)
# - Sequence Models using RNN/LSTM
#
# ## 12. Introduction to Generative Models
# - Autoencoders (Basics)
# - GANs (Generative Adversarial Networks – Just Introduction)
#
# ## 13. Projects (Optional Suggestions)
# - Handwritten Digit Recognition (MNIST)
# - Image Classifier using CNN
# - Sentiment Analysis using LSTM
# - Face Mask Detector
